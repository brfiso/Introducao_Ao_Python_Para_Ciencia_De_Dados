# %% [markdown]
# # Olá, mundo!

# %%
print("Olá, mundo!")
# Out:
# Olá, mundo!

# %% [markdown]
# # Sintaxe

# %%
minha_idade = 33

if minha_idade > 18:
    print("Você é maior de idade!")
else:
    print ("Você é menor de idade.")
# Out:
# Você é maior de idade!

# %% [markdown]
# # Variáveis

# %%
idade = 30
salario = 2000.00
nome = "Maria"
cidade = "Brasília DF"
mora_no_brasil = True

# %% [markdown]
# # Operadores Matemáticos

# %%
1 + 1           # Adição
15 - 5          # Subtração
10 * 2          # Multiplicação
50 / 2          # Divisão

10 % 3          # resto da divisão

10 == 10        # Igual

x = 10          # Atribuição (A variável x "recebe" o valor 10)
# Out:
# False

# %% [markdown]
# # Operadores Lógicos

# %%
x = 10

x != 10                 # ! negação
x == 10 and x > 0       # and -> e
x == 10 or x < 0        # or -> ou
# Out:
# True

# %% [markdown]
# # Bloco de Decisão

# %%
if idade < 18:
    print("Você é menor de idade.")
else:
    print("Você é maior de idade.")
# Out:
# Você é maior de idade.

# %% [markdown]
# # Funções

# %%
# retorna a soma de x e y
def somar(x, y): 
    return x + y

# Escreve a variável nome na tela
def escrever_nome():
    print(nome)

# %% [markdown]
# # Bloco de Repetição (for)

# %%
for numero in range(0, 9):
    print(numero)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
for i in range(0, 1000):
    print("Não vou mais ")
# Out:
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# Não vou mais
# ...

# %% [markdown]
# # Entrada e Saída (input / output)

# %%
# função para escrever algo na tela
print("Escreve algo na tela.")
# Out:
# Escreve algo na tela.

# %%
# Recebe um valor digitado pelo usuário
nome = input("Qual é o seu nome?")

print(f"Olá, {nome}!")
# Out:
# Olá, Brun!

# %% [markdown]
# # Tudo junto!
# Podemos combinar todos esses fluxos e criar algo bem legal!

# %%
for numero in range(1, 1000000):
    bom_professor = input(f'[{numero}/100000] {nome} é um bom professor? (sim | não)')

    if(bom_professor == "sim"):
        print("\n--------------------------\n✅ Ótima resposta!!! 😃\n--------------------------")
        break
    else:
        print("Resposta errada, tente outra vez:")
# Out:
# Resposta errada, tente outra vez:
# Resposta errada, tente outra vez:
# Resposta errada, tente outra vez:
#
# --------------------------
# ✅ Ótima resposta!!! 😃
# --------------------------
